# %% [markdown]
# # Understanding?

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
transactions_df = pd.read_csv("../data/raw/transactions.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
transactions_df.head()
# Out:
#     transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 0   1-11-2018-8205            11               1        مبايعات
# 1  1-11-2016-12930            11               1        مبايعات
# 2  1-11-2016-13524            11               1        مبايعات
# 3   2-13-2014-4939            13               2           رهون
# 4     1-11-2002-81            11               1        مبايعات
#
#   trans_group_en procedure_name_ar      procedure_name_en instance_date  \
# 0          Sales               بيع                   Sell    13-08-2018
# 1          Sales               بيع                   Sell    02-11-2016
# 2          Sales               بيع                   Sell    15-11-2016
# 3      Mortgages         تسجيل رهن  Mortgage Registration    23-06-2014
# 4          Sales               بيع                   Sell    14-01-2002
#
#    property_type_id property_type_ar property_type_en  property_sub_type_id  \
# ...

# %%
transactions_df[transactions_df[['master_project_en', 'project_name_en']].notnull()].sample(10)
# Out:
#         transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 1248139            NaN           NaN             NaN            NaN
# 242611             NaN           NaN             NaN            NaN
# 493996             NaN           NaN             NaN            NaN
# 203534             NaN           NaN             NaN            NaN
# 132563             NaN           NaN             NaN            NaN
# 744243             NaN           NaN             NaN            NaN
# 575128             NaN           NaN             NaN            NaN
# 282362             NaN           NaN             NaN            NaN
# 1210430            NaN           NaN             NaN            NaN
# 824370             NaN           NaN             NaN            NaN
#
#         trans_group_en procedure_name_ar procedure_name_en instance_date  \
# 1248139            NaN               NaN               NaN           NaN
# ...

# %%
transactions_df[transactions_df['master_project_en'].notnull() & transactions_df['project_name_en'].notnull()].sample(10)
# Out:
#            transaction_id  procedure_id  trans_group_id trans_group_ar  \
# 914021   1-102-2019-10516           102               1        مبايعات
# 307490    1-102-2005-3925           102               1        مبايعات
# 335732     1-11-2011-7180            11               1        مبايعات
# 1055085    1-102-2020-505           102               1        مبايعات
# 100877   1-102-2023-68023           102               1        مبايعات
# 479510   1-102-2014-15153           102               1        مبايعات
# 906572   1-102-2022-19080           102               1        مبايعات
# 332102    1-11-2010-16386            11               1        مبايعات
# 1298959   1-11-2018-11314            11               1        مبايعات
# 434079    1-11-2022-32237            11               1        مبايعات
#
#         trans_group_en  procedure_name_ar        procedure_name_en  \
# 914021           Sales  بيع - تسجيل مبدئى  Sell - Pre registration
# ...

# %%
projects_df = pd.read_csv("../data/raw/projects.csv")

# %%
projects_df.head()
# Out:
#    project_id  project_number   project_name  developer_id  developer_number  \
# 0         139             139        دايموند          48.0              48.0
# 1         146             146         نيلوفر          54.0              54.0
# 2         159             159      برج برايم          65.0              65.0
# 3          41              41  51 @ بزنس باي          15.0              15.0
# 4          46              46   برج برلنجتون          15.0              15.0
#
#                     developer_name  master_developer_id  \
# 0  مدينة دبي الرياضية (ش. ذ. م. م)                  200
# 1           دبي للعقارات (ش.ذ.م.م)                  850
# 2         الخليج التجاري (ش.ذ.م.م)                  898
# 3           دبي للعقارات (ش.ذ.م.م)                  850
# 4         الخليج التجاري (ش.ذ.م.م)                  898
#
#    master_developer_number            master_developer_name  \
# 0                      200  مدينة دبي الرياضية (ش. ذ. م. م)
# ...

# %%
assert all(projects_df['developer_name']) == all(projects_df['master_developer_name'])

# %%
projects_df.shape
# Out:
# (2362, 37)

# %%
projects_df[projects_df['project_name'].str.contains("وينر")]
# Out:
#       project_id  project_number project_name  developer_id  developer_number  \
# 2322   594499141            2991   وينر تاور    491560189.0            1579.0
#
#             developer_name  master_developer_id  master_developer_number  \
# 2322  قرية جميرا (ش.ذ.م.م)                  102                      102
#
#      master_developer_name project_start_date project_end_date  \
# 2322  قرية جميرا (ش.ذ.م.م)         15-03-2024              NaN
#
#       project_type_id project_type_ar  project_classification_id  \
# 2322                1            عادي                          1
#
#      project_classification_ar  escrow_agent_id     escrow_agent_name  \
# 2322                     مباني              4.0  مصرف ابوظبى الاسلامى
#
#      project_status project_status_ar  percent_completed completion_date  \
# 2322    NOT_STARTED       تحت الانشاء                0.0             NaN
#
#      cancellation_date                             project_description_ar  \
# ...

# %%
projects_df['project_status'].value_counts()
# Out:
# project_status
# FINISHED                  1304
# ACTIVE                     510
# NOT_STARTED                366
# PENDING                    161
# CONDITIONAL_ACTIVATING      19
# STOPPED                      1
# FRIEZED                      1
# Name: count, dtype: int64

# %%
projects_df[projects_df['project_status'] == 'ACTIVE'].sample(5)
# Out:
#       project_id  project_number                 project_name  developer_id  \
# 1657   409768169            2382  أفا أت بالم جميرا من أمنيات   404112355.0
# 226    510549918            2691                    أوشن هاوس   457105107.0
# 663          685             685                       الفيلا         784.0
# 846    487283558            2602                   قنال هايتس   478849981.0
# 1670   427035961            2433                 سامانا ميامي   365931634.0
#
#       developer_number                 developer_name  master_developer_id  \
# 1657            1407.0  شركة النخلة - جميرا (ش.ذ.م.م)                  103
# 226             1513.0  شركة النخلة - جميرا (ش.ذ.م.م)                  103
# 663              784.0         دبي للعقارات (ش.ذ.م.م)                  850
# 846             1552.0       الخليج التجاري (ش.ذ.م.م)                  898
# 1670            1344.0              شركة نخيل (ش.م.خ)                  100
#
# ...

# %%
projects_df.loc[projects_df['project']]
